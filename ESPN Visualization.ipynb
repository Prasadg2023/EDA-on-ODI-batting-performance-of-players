# %% [markdown]
# # Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# # Reading CSV File "cricket_clean_dataset.csv"

# %%
df = pd.read_csv("Player_stats_Clean_Dataset.csv")

# %%
df
# Out:
#         Player_Names               Country  Start_Year  End_Year  Matches  \
# 0      SR Tendulkar                  India        1989      2012      463
# 1           V Kohli                  India        2008      2025      308
# 2     KC Sangakkara              Sri Lanka        2000      2015      404
# 3        RT Ponting              Australia        1995      2012      375
# 4     ST Jayasuriya              Sri Lanka        1989      2011      445
# ..               ...                   ...         ...       ...      ...
# 739      PR Reiffel              Australia        1992      1999       92
# 740        AR Nurse            West Indies        2016      2019       54
# 741      JE Emburey                England        1980      1993       61
# 742  Ghulam Shabber   United Arab Emirates        2017      2019       23
# 743        GP Swann                England        2000      2013       79
#
#      Innings  Not_Out  Total_Runs  Highest_Score  Batting_Average  Ball_Faced  \
# 0        452       41       18426            200            44.83       21368
# 1        296       47       14557            183            58.46       15543
# 2        380       41       14234            169            41.98       18048
# 3        365       39       13704            164            42.03       17046
# 4        433       18       13430            189            32.36       14725
# ..       ...      ...         ...            ...              ...         ...
# 739       57       21         503             58            13.97         709
# 740       40       14         502             44            19.30         513
# 741       45       10         501             34            14.31         664
# 742       23        0         500             90            21.73         800
# 743       48       12         500             34            13.88         553
#
#      Strike_Rate  100's  50's
# 0          86.23     49    96
# 1          93.65     53    76
# 2          78.86     25    93
# 3          80.39     30    82
# 4          91.20     28    68
# ..           ...    ...   ...
# 739        70.94      0     1
# 740        97.85      0     0
# 741        75.45      0     0
# 742        62.50      0     4
# 743        90.41      0     0
#
# [744 rows x 14 columns]

# %%
df.head(10)
# Out:
#         Player_Names       Country  Start_Year  End_Year  Matches  Innings  \
# 0      SR Tendulkar          India        1989      2012      463      452
# 1           V Kohli          India        2008      2025      308      296
# 2     KC Sangakkara      Sri Lanka        2000      2015      404      380
# 3        RT Ponting      Australia        1995      2012      375      365
# 4     ST Jayasuriya      Sri Lanka        1989      2011      445      433
# 5  DPMD Jayawardene      Sri Lanka        1998      2015      448      418
# 6    Inzamam-ul-Haq       Pakistan        1991      2007      378      350
# 7         JH Kallis   South Africa        1996      2014      328      314
# 8         RG Sharma          India        2007      2025      279      271
# 9        SC Ganguly          India        1992      2007      311      300
#
#    Not_Out  Total_Runs  Highest_Score  Batting_Average  Ball_Faced  \
# 0       41       18426            200            44.83       21368
# 1       47       14557            183            58.46       15543
# 2       41       14234            169            41.98       18048
# 3       39       13704            164            42.03       17046
# 4       18       13430            189            32.36       14725
# 5       39       12650            144            33.37       16020
# 6       53       11739            137            39.52       15812
# 7       53       11579            139            44.36       15885
# 8       37       11516            264            49.21       12402
# 9       23       11363            183            41.02       15416
#
#    Strike_Rate  100's  50's
# 0        86.23     49    96
# 1        93.65     53    76
# 2        78.86     25    93
# 3        80.39     30    82
# 4        91.20     28    68
# 5        78.96     19    77
# 6        74.24     10    83
# 7        72.89     17    86
# 8        92.85     33    61
# 9        73.70     22    72

# %% [markdown]
# # Checking shape of Dataset

# %%
df.shape
# Out:
# (744, 14)

# %% [markdown]
# # Observation

# %% [markdown]
# ## The DataFreame Having 744 rows and 14 columns

# %% [markdown]
# ### Here we have to change the data dtaa type of start_yar and end_year for further visualization

# %%
df[["Start_Year","End_Year"]] = df[["Start_Year","End_Year"]].astype(object)

# %%
df['Start_Year'] = pd.to_datetime(df['Start_Year'], format='%Y')
df['End_Year'] = pd.to_datetime(df['End_Year'], format='%Y')

print(df[['Start_Year', 'End_Year']].dtypes)
# Out:
# Start_Year    datetime64[ns]
# End_Year      datetime64[ns]
# dtype: object

# %% [markdown]
# # Now checking the DataFrame info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Player_Names     744 non-null    object
#  1   Country          744 non-null    object
#  2   Start_Year       744 non-null    datetime64[ns]
#  3   End_Year         744 non-null    datetime64[ns]
#  4   Matches          744 non-null    int64
#  5   Innings          744 non-null    int64
#  6   Not_Out          744 non-null    int64
#  7   Total_Runs       744 non-null    int64
#  8   Highest_Score    744 non-null    int64
#  9   Batting_Average  744 non-null    float64
#  10  Ball_Faced       744 non-null    int64
#  11  Strike_Rate      744 non-null    float64
#  12  100's            744 non-null    int64
#  13  50's             744 non-null    int64
# dtypes: datetime64[ns](2), float64(2), int64(8), object(2)
# memory usage: 81.5+ KB

# %% [markdown]
# # Observation:-

# %% [markdown]
# ## In this DataFrame there are 2 float,8 int, and 2 object and 2 datetime64[ns] data types

# %% [markdown]
# # Statistical distribution

# %%
df.describe()
# Out:
#                           Start_Year                       End_Year  \
# count                            744                            744
# mean   2002-08-25 00:03:52.258064512  2011-07-27 20:13:32.903225600
# min              1971-01-01 00:00:00            1977-01-01 00:00:00
# 25%              1993-01-01 00:00:00            2003-01-01 00:00:00
# 50%              2004-01-01 00:00:00            2014-01-01 00:00:00
# 75%              2014-01-01 00:00:00            2023-01-01 00:00:00
# max              2025-01-01 00:00:00            2025-01-01 00:00:00
# std                              NaN                            NaN
#
#           Matches     Innings     Not_Out    Total_Runs  Highest_Score  \
# count  744.000000  744.000000  744.000000    744.000000     744.000000
# mean    98.038978   85.817204   12.657258   2312.991935     107.451613
# min     12.000000   12.000000    0.000000    500.000000      26.000000
# 25%     42.000000   39.000000    3.000000    807.250000      81.000000
# 50%     71.000000   61.000000    8.000000   1325.000000     106.000000
# 75%    127.250000  110.000000   17.250000   2743.250000     130.000000
# max    463.000000  452.000000   84.000000  18426.000000     264.000000
# std     77.837044   69.724773   13.440142   2429.981222      36.748175
#
#        Batting_Average    Ball_Faced  Strike_Rate       100's        50's
# count       744.000000    744.000000   744.000000  744.000000  744.000000
# mean         29.647957   2984.567204    77.746089    2.826613   12.926075
# min           6.800000    492.000000    45.530000    0.000000    0.000000
# 25%          23.237500   1050.750000    68.085000    0.000000    4.000000
# 50%          28.630000   1760.500000    76.375000    1.000000    7.000000
# 75%          35.850000   3614.000000    86.215000    3.000000   16.000000
# max          67.730000  21368.000000   130.220000   53.000000   96.000000
# std           9.430893   3029.368330    13.592561    5.310371   15.321891

# %% [markdown]
# # It gives without object columns so for object column

# %%
df['Player_Names'].value_counts().head(10)
# Out:
# Player_Names
# SC Williams        2
# Yuvraj Singh       1
# PK Amre            1
# KM Dabengwa        1
# JH Kallis          1
# GP Swann           1
# SR Tendulkar       1
# V Kohli            1
# Inzamam-ul-Haq     1
# RG Sharma          1
# Name: count, dtype: int64

# %%
df = df[df['Player_Names'] != 'SC Williams']

# %%
df.groupby('Player_Names')['Total_Runs'].sum().sort_values(ascending=False).head()
# Out:
# Player_Names
# SR Tendulkar      18426
# V Kohli           14557
# KC Sangakkara     14234
# RT Ponting        13704
# ST Jayasuriya     13430
# Name: Total_Runs, dtype: int64

# %% [markdown]
# # checking duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Observation

# %% [markdown]
# ### There no duplicates

# %% [markdown]
# # Cheking unique values

# %%
df.nunique()
# Out:
# Player_Names       743
# Country             27
# Start_Year          55
# End_Year            47
# Matches            225
# Innings            204
# Not_Out             61
# Total_Runs         636
# Highest_Score      159
# Batting_Average    670
# Ball_Faced         691
# Strike_Rate        673
# 100's               31
# 50's                72
# dtype: int64

# %% [markdown]
# # Observation:-
# ### The dataset includes unique values like
# * 743, Player_Names
# * 27 Country,
# * 55 Start_Year,
# * 47 End_Year,
# * 225 Matches,
# * 204 Innings,
# * 61 Not_Out,
# * 636 Total_Runs,
# * 169 Highest_Score,
# * 670 Batting_Average,
# * 691 Ball_Faced,
# * 673 Strike_Rate,
# * 31 => 100's
# * 72 => 50's

# %% [markdown]
# # Checking Correlation for numerical columns

# %%
df.corr(numeric_only = True)
# Out:
#                   Matches   Innings   Not_Out  Total_Runs  Highest_Score  \
# Matches          1.000000  0.971626  0.814873    0.843073       0.303404
# Innings          0.971626  1.000000  0.712879    0.929904       0.426438
# Not_Out          0.814873  0.712879  1.000000    0.531319       0.020891
# Total_Runs       0.843073  0.929904  0.531319    1.000000       0.605775
# Highest_Score    0.303404  0.426438  0.020891    0.605775       1.000000
# Batting_Average  0.104007  0.221986  0.017093    0.475970       0.705153
# Ball_Faced       0.833771  0.923910  0.523491    0.983359       0.564026
# Strike_Rate      0.078621  0.067181  0.078168    0.111240       0.270692
# 100's            0.593932  0.686129  0.272524    0.856073       0.651036
# 50's             0.774262  0.874449  0.470555    0.972707       0.597568
#
#                  Batting_Average  Ball_Faced  Strike_Rate     100's      50's
# Matches                 0.104007    0.833771     0.078621  0.593932  0.774262
# Innings                 0.221986    0.923910     0.067181  0.686129  0.874449
# Not_Out                 0.017093    0.523491     0.078168  0.272524  0.470555
# Total_Runs              0.475970    0.983359     0.111240  0.856073  0.972707
# Highest_Score           0.705153    0.564026     0.270692  0.651036  0.597568
# Batting_Average         1.000000    0.445573     0.273282  0.534950  0.527195
# Ball_Faced              0.445573    1.000000    -0.018323  0.804160  0.971419
# Strike_Rate             0.273282   -0.018323     1.000000  0.188682  0.071041
# 100's                   0.534950    0.804160     0.188682  1.000000  0.790458
# 50's                    0.527195    0.971419     0.071041  0.790458  1.000000

# %% [markdown]
# # Steps
# ## 1) Univariate Analysis (Single Column)
#
# * Distribution of one variable
#
# * Count, histogram, boxplot

# %% [markdown]
# # 2) Bivariate Analysis (Two Columns)
#
# ## Relationship between two columns
#
# ### Examples:
#
# * Numeric vs Numeric → scatter plot
#
# * Numeric vs Categorical → box plot
#
# * Categorical vs Categorical → count plot

# %% [markdown]
# # 1) Univariate Analysis - Statistical
# ## I) For Numerical Columns

# %%
df.columns
# Out:
# Index(['Player_Names', 'Country', 'Start_Year', 'End_Year', 'Matches',
#        'Innings', 'Not_Out', 'Total_Runs', 'Highest_Score', 'Batting_Average',
#        'Ball_Faced', 'Strike_Rate', '100's', '50's'],
#       dtype='object')

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64'])
def numerical_univariate_analysis(numerical_data):
    for col_name in numerical_data:
        print(col_name)
        print(numerical_data[col_name].agg(['min', 'max', 'mean', 'median', 'std']))
        print()

# %%
numerical_univariate_analysis(numerical_cols)
# Out:
# Matches
# min        12.000000
# max       463.000000
# mean       98.038978
# median     71.000000
# std        77.837044
# Name: Matches, dtype: float64
#
# Innings
# min        12.000000
# max       452.000000
# mean       85.817204
# median     61.000000
# std        69.724773
# Name: Innings, dtype: float64
#
# Not_Out
# min        0.000000
# max       84.000000
# mean      12.657258
# median     8.000000
# std       13.440142
# Name: Not_Out, dtype: float64
#
# Total_Runs
# min         500.000000
# max       18426.000000
# mean       2312.991935
# median     1325.000000
# std        2429.981222
# Name: Total_Runs, dtype: float64
#
# Highest_Score
# min        26.000000
# max       264.000000
# mean      107.451613
# median    106.000000
# std        36.748175
# Name: Highest_Score, dtype: float64
#
# Batting_Average
# min        6.800000
# max       67.730000
# mean      29.647957
# median    28.630000
# std        9.430893
# Name: Batting_Average, dtype: float64
#
# Ball_Faced
# min         492.000000
# max       21368.000000
# mean       2984.567204
# median     1760.500000
# std        3029.368330
# Name: Ball_Faced, dtype: float64
#
# Strike_Rate
# min        45.530000
# max       130.220000
# mean       77.746089
# median     76.375000
# std        13.592561
# Name: Strike_Rate, dtype: float64
#
# 100's
# min        0.000000
# max       53.000000
# mean       2.826613
# median     1.000000
# std        5.310371
# Name: 100's, dtype: float64
#
# 50's
# min        0.000000
# max       96.000000
# mean      12.926075
# median     7.000000
# std       15.321891
# Name: 50's, dtype: float64

# %% [markdown]
# ## II) For Categorical Columns

# %%
categorical_cols = df.select_dtypes(include=['object'])
def categorical_univariate_analysis(categorical_data): 
    for col_name in categorical_data:
        print(col_name)
        print(categorical_data[col_name].agg(['count', 'nunique', 'unique']))
        print()

# %%
categorical_univariate_analysis(categorical_cols)
# Out:
# Player_Names
# count                                                    744
# nunique                                                  743
# unique     [SR Tendulkar , V Kohli , KC Sangakkara , RT P...
# Name: Player_Names, dtype: object
#
# Country
# count                                                    744
# nunique                                                   27
# unique     [India, Sri Lanka, Australia, Pakistan, South ...
# Name: Country, dtype: object

# %% [markdown]
# # Univariate Plots
# ## I) Numerical Columns

# %%
for col in numerical_cols: 
    # Plots
    plt.figure(figsize=(12, 4))
    
    # Histogram
    plt.subplot(1, 2, 1)
    sns.histplot(df[col], kde=True, bins=20, color="skyblue")
    plt.title(f"{col} - Distribution")
    
    # Boxplot
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[col], color="lightgreen")
    plt.title(f"{col} - Boxplot")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Univariate Plots
# ## II) Categorical Columns

# %%
for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    top_values = df[col].value_counts().head(5)
    sns.barplot(x=top_values.values,y=top_values.index, hue = top_values.index,legend=True, palette = "cool")
    plt.title(f"Top 5 {col}")
    plt.xlabel("Count")
    plt.ylabel(col)
    plt.tight_layout()
    plt.show()

# %%
# Get top 5 countries
top5 = df['Country'].value_counts().head(5)

# Plot pie chart
plt.figure(figsize=(8, 6))
top5.plot(kind='pie', autopct='%1.f%%', startangle=90, colormap='Set3')
plt.title("Top 5 Countries Representation")
plt.ylabel("")  # Remove default y-label
plt.tight_layout()
plt.show()

# %%
df['Career_Length'] = (df['End_Year'].dt.year - df['Start_Year'].dt.year)

# %% [markdown]
# # 2. Bivariate Analysis
# ## Count of Players by Country

# %%
country_counts = df['Country'].value_counts()
plt.figure(figsize=(8,5))
ax = sns.barplot(x=country_counts.values, y=country_counts.index, palette='cool')
for i in ax.containers:
    ax.bar_label(i)
plt.title("Number of Players per Country")
plt.xlabel("Number of Players")
plt.ylabel("Country")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation:-
# * Top cricketing nations: New Zealand, Australia, Pakistan, India, West Indies, and England each have 40+ players.
#
# * Mid-tier nations: Sri Lanka and South Africa have moderate representation.
#
# * Lower-tier nations: Zimbabwe, Bangladesh, Afghanistan, and others contribute fewer players.

# %% [markdown]
# # Highest total_runs in top 10 run scorer

# %%
top_runs = df.nlargest(10, 'Total_Runs')
plt.figure(figsize=(12,6))
ax = sns.barplot(x='Total_Runs', y='Player_Names', data=top_runs, palette='Blues_r')

for i in ax.containers:
    ax.bar_label(i)
    
plt.title("Top 10 Run Scorers", fontsize=14)
plt.xlabel("Total Runs")
plt.ylabel("Player")
plt.show()

# %% [markdown]
# # Observation:-
# * Sachin Tendulkar dominates with over 18,000 runs, far ahead of all other players, showing his unmatched consistency.
#
# * Kumar Sangakkara and Virat Kohli follow closely behind, both with over 14,000 runs, proving their exceptional performance.
#
# * The rest of the players (Ponting, Jayasuriya, Jayawardene, etc.) have impressive tallies between 11,000–13,000 runs, but there’s a noticeable gap compared to the top scorer.

# %% [markdown]
# # Higheest total runs for each country

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Country', y='Total_Runs', palette = "cool",data=df, estimator=np.sum, errorbar=None)
plt.xticks(rotation=60)
plt.title("Total Runs by Country (Sum)")
plt.show()

# %% [markdown]
# # Observation:-
# * India dominates with the highest total runs, showing strong batting depth over time.
#
# * Sri Lanka, Australia, and Pakistan also have very high totals, forming the next strongest group.
#
# * Smaller cricket nations like Nepal, Oman, and UAE have much lower totals, highlighting fewer matches or less experience.

# %% [markdown]
# # Top 10 Players BY ceturies

# %%
top_100s = df.nlargest(10, "100's")
plt.figure(figsize=(10,6))
ax = sns.barplot(x="100's", y="Player_Names", data=top_100s, palette='Greens_r')

for i in ax.containers:
    ax.bar_label(i)
    
plt.title("Top 10 Players by Centuries", fontsize=14)
plt.xlabel("Centuries")
plt.ylabel("Player")
plt.show()

# %% [markdown]
# # Observation:-
# * Top Performers: Virat Kohli and Sachin Tendulkar are clear leaders with 51 and 49 centuries, far ahead of others.
#
# * Mid-tier Group: Players like Rohit Sharma, Ponting, and Jayasuriya are in the 30–28 century range, showing consistent performance.
#
# * Close Competition: Several legends like Sangakkara, Gayle, and AB de Villiers are tied at 25 centuries, highlighting a competitive group.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert to datetime (assuming only year is given)
df['Start_Year'] = pd.to_datetime(df['Start_Year'], format='%Y', errors='coerce')
df['End_Year'] = pd.to_datetime(df['End_Year'], format='%Y', errors='coerce')

# Calculate career length in years
df['Career_Length'] = df['End_Year'].dt.year - df['Start_Year'].dt.year

# Create a year range for each player's active years
all_years = []
for i, row in df.iterrows():
    if pd.notnull(row['Start_Year']) and pd.notnull(row['End_Year']):
        all_years.extend(range(row['Start_Year'].year, row['End_Year'].year + 1))

# Count number of active players each year
yearly_counts = pd.Series(all_years).value_counts().sort_index()

# Plot trend
plt.figure(figsize=(12,6))
plt.plot(yearly_counts.index, yearly_counts.values, marker='o', linestyle='-', color='b')
plt.title("Number of Active Players Over Time")
plt.xlabel("Year")
plt.ylabel("Number of Players Active")
plt.grid(True)
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
plt.figure(figsize=(10,6))
sns.regplot(
    data=df,
    x='Matches',
    y='Total_Runs',
    scatter=False,       
    color='red',        
    line_kws={'linewidth':2}
)
sns.scatterplot(
    data=df,
    x='Matches',
    y='Total_Runs',
    hue='Country',        
    size='Batting_Average',
    alpha=0.7,
    sizes=(40, 400)
)
plt.title("Matches vs Total Runs (One Regression Line, Color=Country, Size=Batting Avg)", fontsize=14)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# # Observation:-
# * Players with more matches generally score higher total runs, showing a strong positive relationship between career length and total performance.
#
# * Batting averages vary widely – some players maintain high averages even with fewer matches, while others achieve consistency over long careers.
#
# * Country-wise clustering is visible, with top cricketing nations dominating the higher runs and match counts compared to smaller cricket nations.

# %%
# heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(numerical_cols.corr(), annot=True, cmap='coolwarm',fmt='.2f')
plt.title("Correlation Heatmap of Numerical Features")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation:-
# * Total runs increase mainly with matches and innings played.
#
# * Batting average and strike rate are largely independent of matches, innings, and total runs.
#
# * Strong correlations exist between Matches, Innings, and Total Runs, but not with performance efficiency metrics.

# %%
# Bubble Plot 
top_df = df.head(10)
plt.figure(figsize=(12,7))
plt.scatter(top_df['Matches'], top_df['Total_Runs'],
            s=top_df['Strike_Rate']*2, alpha=0.6, edgecolors='black', c=top_df['Batting_Average'], cmap='plasma')
for i in range(top_df.shape[0]):
    plt.text(top_df['Matches'].iloc[i]+0.5, top_df['Total_Runs'].iloc[i],
             top_df['Player_Names'].iloc[i], fontsize=8)
plt.colorbar(label="Batting Average")
plt.xlabel("Matches")
plt.ylabel("Total Runs")
plt.title("Bubble Plot: Matches vs Runs (Color=Batting Avg, Size=Strike Rate)", fontsize=16)
plt.show()

# %% [markdown]
# # Observation:-
# * More matches = more runs – Players who played more matches generally scored more runs.
#
# * Kohli has best average – Even with fewer matches, Virat Kohli has the highest batting average.
#
# * Big hitters have high strike rates – Players like Sehwag and Gayle score faster, shown by larger bubbles.

# %%
hfjgdgf

# %% [markdown]
# ## thankyou
